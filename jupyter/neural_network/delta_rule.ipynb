# %% [markdown]
# ### The Delta Rule

# %%
# %run core.ipynb

# %% [markdown]
#    #### Delta Rule Implementation

# %%
# %load delta_rule.py
import random
from vector import dotprod


def delta_rule(T, a, da, s=0.01, epochs=50):
    n = len(T[0][0])
    w, b = tuple(random.random() for _ in range(n)), random.random()
    for _ in range(epochs):
        for x, y in T:
            z = dotprod(w, x) + b
            az, daz = a(z), da(z)
            d = y - az
            t = s * d * daz
            w = tuple(w[i] + t * x[i] for i in range(n))
            b = b + t
    return w, b

# %%
def delta_rule_approx(T, a, da, s=0.01, epochs=50):
    w, b = delta_rule(T, a=a, da=da, s=s, epochs=epochs)
    return lambda x: dotprod(w, x) + b


def run_delta_rule(f, T, a, da, classify, s=0.01, epochs=50):
    r = delta_rule_approx(T, a, da, s=s, epochs=epochs)
    p = lambda x: classify(r(x))
    if all(p(x) == y for x, y in T):
        print(f"{f.__name__}:")
    else:
        print(_red(f"{f.__name__}:"))
    for x, y in T:
        z = p(x)
        if z == y:
            print(f"    {f.__name__}{x} = {y}	a(wx+b) = {_rnd(a(r(x)), n=2)} {_ok}")
        else:
            print(_red(f"    {f.__name__}{x} = {y} ≠ {z}	a(wx+b) = {_rnd(a(r(x)), n=2)} {_nok}"))

# %% [markdown]
# #### Approximation of Boolean Operators

# %%
s, epochs = 0.01, 2500
for f, T in BOOLEAN_TESTDATA.items():
    run_delta_rule(f, T, a=sigmoid, da=dx_sigmoid, classify=heaviside, s=s, epochs=epochs)
# Out:
# AND:
#     AND(0, 0) = 0	a(wx+b) = 0.11 ✔
#     AND(0, 1) = 0	a(wx+b) = 0.29 ✔
#     AND(1, 0) = 0	a(wx+b) = 0.31 ✔
#     AND(1, 1) = 1	a(wx+b) = 0.6 ✔
# OR:
#     OR(0, 0) = 0	a(wx+b) = 0.42 ✔
#     OR(0, 1) = 1	a(wx+b) = 0.81 ✔
#     OR(1, 0) = 1	a(wx+b) = 0.77 ✔
#     OR(1, 1) = 1	a(wx+b) = 0.95 ✔
# NAND:
#     NAND(0, 0) = 1	a(wx+b) = 0.58 ✔
#     NAND(0, 1) = 0	a(wx+b) = 0.22 ✔
#     NAND(1, 0) = 0	a(wx+b) = 0.21 ✔
#     NAND(1, 1) = 0	a(wx+b) = 0.05 ✔
# XOR:
#     XOR(0, 0) = 0	a(wx+b) = 0.47 ✔
#     XOR(0, 1) = 1 ≠ 0	a(wx+b) = 0.49 ✗
#     XOR(1, 0) = 1	a(wx+b) = 0.5 ✔
#     XOR(1, 1) = 0 ≠ 1	a(wx+b) = 0.52 ✗

# %%
s, epochs = 0.01, 500
r = 10.0 * random.random()
a, da = lambda x: linear(x, a=r), lambda x: dx_linear(x, a=r)
classify = lambda x: heaviside(x, offset=0.5)
for f, T in BOOLEAN_TESTDATA.items():
    run_delta_rule(f, T, a=linear, da=dx_linear, classify=classify, s=s, epochs=epochs)
# Out:
# AND:
#     AND(0, 0) = 0	a(wx+b) = -0.25 ✔
#     AND(0, 1) = 0	a(wx+b) = 0.25 ✔
#     AND(1, 0) = 0	a(wx+b) = 0.25 ✔
#     AND(1, 1) = 1	a(wx+b) = 0.75 ✔
# OR:
#     OR(0, 0) = 0	a(wx+b) = 0.25 ✔
#     OR(0, 1) = 1	a(wx+b) = 0.75 ✔
#     OR(1, 0) = 1	a(wx+b) = 0.75 ✔
#     OR(1, 1) = 1	a(wx+b) = 1.25 ✔
# NAND:
#     NAND(0, 0) = 1	a(wx+b) = 0.71 ✔
#     NAND(0, 1) = 0	a(wx+b) = 0.24 ✔
#     NAND(1, 0) = 0	a(wx+b) = 0.25 ✔
#     NAND(1, 1) = 0	a(wx+b) = -0.22 ✔
# XOR:
#     XOR(0, 0) = 0	a(wx+b) = 0.49 ✔
#     XOR(0, 1) = 1 ≠ 0	a(wx+b) = 0.5 ✗
#     XOR(1, 0) = 1 ≠ 0	a(wx+b) = 0.49 ✗
#     XOR(1, 1) = 0	a(wx+b) = 0.5 ✔

# %%
s, epochs = 0.01, 500
for f, T in BOOLEAN_TESTDATA.items():
    run_delta_rule(f, T, a=tanh, da=dx_tanh, classify=classify, s=s, epochs=epochs)
# Out:
# AND:
#     AND(0, 0) = 0	a(wx+b) = -0.21 ✔
#     AND(0, 1) = 0	a(wx+b) = 0.23 ✔
#     AND(1, 0) = 0	a(wx+b) = 0.26 ✔
#     AND(1, 1) = 1	a(wx+b) = 0.61 ✔
# OR:
#     OR(0, 0) = 0	a(wx+b) = 0.15 ✔
#     OR(0, 1) = 1	a(wx+b) = 0.84 ✔
#     OR(1, 0) = 1	a(wx+b) = 0.8 ✔
#     OR(1, 1) = 1	a(wx+b) = 0.97 ✔
# NAND:
#     NAND(0, 0) = 1	a(wx+b) = 0.58 ✔
#     NAND(0, 1) = 0	a(wx+b) = 0.23 ✔
#     NAND(1, 0) = 0	a(wx+b) = 0.23 ✔
#     NAND(1, 1) = 0	a(wx+b) = -0.2 ✔
# XOR:
#     XOR(0, 0) = 0	a(wx+b) = 0.25 ✔
#     XOR(0, 1) = 1	a(wx+b) = 0.6 ✔
#     XOR(1, 0) = 1	a(wx+b) = 0.59 ✔
#     XOR(1, 1) = 0 ≠ 1	a(wx+b) = 0.81 ✗

# %% [markdown]
# #### Approximation Analysis

# %% [markdown]
# Calculate and verify approximation of a separable boolean operator. Run a number of trials to ensure the approximation is stable under the given step length and number of epochs.

# %% [markdown]
# Choosing identical weights for initialization actually seems to reduce the number of required epochs by ½!?

# %%
def check_boolean_approx(f, a, da, classify, s=0.01, epochs=50, trials=25):
    T = BOOLEAN_TESTDATA[f]
    for _ in range(trials):
        w, b = delta_rule(T, a=a, da=da, s=s, epochs=epochs)
        p = lambda x: classify(dotprod(w, x) + b)
        if not all(p(x) == y for x, y in T):
            return False, (None, None)
    return True, (normed(w), b / norm(w))

# %% [markdown]
# Use pandas to display combinations of step length and smallest number of epochs that can be used to approximate a separable boolean operator.

# %%
import pandas as pd


def analyze_boolean_approx(f, a, da, classify, S, E, trials):
    data = []
    for s in S:
        for epochs in sorted(E):
            ok, (w, b) = check_boolean_approx(f, a, da, classify, s=s, epochs=epochs, trials=trials)
            if ok:
                data.append([s, epochs, _rnd(w), _rnd(b)])
                break
    df = pd.DataFrame(data, columns=["Step Length", "Min Epochs", "Weight", "Bias"])
    display(df.style.hide_index())

# %%
trials = 25
S = [0.01, 0.05, 0.1, 0.5, 1.0, 5.0]
E = [10, 25, 50, 100, 250, 500, 1000, 2500, 5000]

# %%
a, da, classify = sigmoid, dx_sigmoid, heaviside
analyze_boolean_approx(AND, a, da, classify, S, E, trials)
# Out:
# <style  type="text/css" >
# </style><table id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017" ><thead>    <tr>        <th class="col_heading level0 col0" >Step Length</th>        <th class="col_heading level0 col1" >Min Epochs</th>        <th class="col_heading level0 col2" >Weight</th>        <th class="col_heading level0 col3" >Bias</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row0_col0" class="data row0 col0" >0.010000</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row0_col1" class="data row0 col1" >2500</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row0_col2" class="data row0 col2" >(0.7, 0.72)</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row0_col3" class="data row0 col3" >-1.170000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row1_col0" class="data row1 col0" >0.050000</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row1_col1" class="data row1 col1" >500</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row1_col2" class="data row1 col2" >(0.74, 0.67)</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row1_col3" class="data row1 col3" >-1.170000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row2_col0" class="data row2 col0" >0.100000</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row2_col1" class="data row2 col1" >250</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row2_col2" class="data row2 col2" >(0.66, 0.75)</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row2_col3" class="data row2 col3" >-1.190000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row3_col0" class="data row3 col0" >0.500000</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row3_col1" class="data row3 col1" >25</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row3_col2" class="data row3 col2" >(0.73, 0.68)</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row3_col3" class="data row3 col3" >-1.250000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row4_col0" class="data row4 col0" >1.000000</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row4_col1" class="data row4 col1" >10</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row4_col2" class="data row4 col2" >(0.79, 0.61)</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row4_col3" class="data row4 col3" >-1.210000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row5_col0" class="data row5 col0" >5.000000</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row5_col1" class="data row5 col1" >10</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row5_col2" class="data row5 col2" >(0.76, 0.65)</td>
#                         <td id="T_b7f80bd6_6558_11ea_93fd_38c9861cb017row5_col3" class="data row5 col3" >-0.900000</td>
#             </tr>
#     </tbody></table>

# %%
a, da, classify = lambda x: 0.5 * linear(x) + 0.5, lambda x: 0.5 * dx_linear(x), heaviside
analyze_boolean_approx(NAND, a, da, classify, S, E, trials)
# Out:
# <style  type="text/css" >
# </style><table id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017" ><thead>    <tr>        <th class="col_heading level0 col0" >Step Length</th>        <th class="col_heading level0 col1" >Min Epochs</th>        <th class="col_heading level0 col2" >Weight</th>        <th class="col_heading level0 col3" >Bias</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row0_col0" class="data row0 col0" >0.010000</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row0_col1" class="data row0 col1" >1000</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row0_col2" class="data row0 col2" >(-0.7, -0.71)</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row0_col3" class="data row0 col3" >0.280000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row1_col0" class="data row1 col0" >0.050000</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row1_col1" class="data row1 col1" >250</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row1_col2" class="data row1 col2" >(-0.7, -0.71)</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row1_col3" class="data row1 col3" >0.260000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row2_col0" class="data row2 col0" >0.100000</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row2_col1" class="data row2 col1" >100</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row2_col2" class="data row2 col2" >(-0.71, -0.71)</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row2_col3" class="data row2 col3" >0.230000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row3_col0" class="data row3 col0" >0.500000</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row3_col1" class="data row3 col1" >25</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row3_col2" class="data row3 col2" >(-0.68, -0.74)</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row3_col3" class="data row3 col3" >0.250000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row4_col0" class="data row4 col0" >1.000000</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row4_col1" class="data row4 col1" >10</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row4_col2" class="data row4 col2" >(-0.62, -0.79)</td>
#                         <td id="T_b83d4f7a_6558_11ea_93fd_38c9861cb017row4_col3" class="data row4 col3" >0.180000</td>
#             </tr>
#     </tbody></table>

# %%
a, da, classify = lambda x: 0.5 * tanh(x) + 0.5, lambda x: 0.5 * dx_tanh(x), heaviside
analyze_boolean_approx(OR, a, da, classify, S, E, trials)
# Out:
# <style  type="text/css" >
# </style><table id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017" ><thead>    <tr>        <th class="col_heading level0 col0" >Step Length</th>        <th class="col_heading level0 col1" >Min Epochs</th>        <th class="col_heading level0 col2" >Weight</th>        <th class="col_heading level0 col3" >Bias</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row0_col0" class="data row0 col0" >0.010000</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row0_col1" class="data row0 col1" >1000</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row0_col2" class="data row0 col2" >(0.7, 0.72)</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row0_col3" class="data row0 col3" >-0.260000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row1_col0" class="data row1 col0" >0.050000</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row1_col1" class="data row1 col1" >250</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row1_col2" class="data row1 col2" >(0.71, 0.7)</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row1_col3" class="data row1 col3" >-0.230000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row2_col0" class="data row2 col0" >0.100000</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row2_col1" class="data row2 col1" >100</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row2_col2" class="data row2 col2" >(0.67, 0.75)</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row2_col3" class="data row2 col3" >-0.220000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row3_col0" class="data row3 col0" >0.500000</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row3_col1" class="data row3 col1" >25</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row3_col2" class="data row3 col2" >(0.69, 0.72)</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row3_col3" class="data row3 col3" >-0.240000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row4_col0" class="data row4 col0" >1.000000</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row4_col1" class="data row4 col1" >10</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row4_col2" class="data row4 col2" >(0.69, 0.73)</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row4_col3" class="data row4 col3" >-0.190000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row5_col0" class="data row5 col0" >5.000000</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row5_col1" class="data row5 col1" >10</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row5_col2" class="data row5 col2" >(0.69, 0.72)</td>
#                         <td id="T_b87b5ca2_6558_11ea_93fd_38c9861cb017row5_col3" class="data row5 col3" >-0.310000</td>
#             </tr>
#     </tbody></table>

# %%
a, da, classify = relu, dx_relu, lambda x: heaviside(x, offset=0.4)
analyze_boolean_approx(AND, a, da, classify, S, E, trials)
# Out:
# <style  type="text/css" >
# </style><table id="T_b8f43c12_6558_11ea_93fd_38c9861cb017" ><thead>    <tr>        <th class="col_heading level0 col0" >Step Length</th>        <th class="col_heading level0 col1" >Min Epochs</th>        <th class="col_heading level0 col2" >Weight</th>        <th class="col_heading level0 col3" >Bias</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row0_col0" class="data row0 col0" >0.010000</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row0_col1" class="data row0 col1" >250</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row0_col2" class="data row0 col2" >(0.72, 0.7)</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row0_col3" class="data row0 col3" >-0.290000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row1_col0" class="data row1 col0" >0.050000</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row1_col1" class="data row1 col1" >25</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row1_col2" class="data row1 col2" >(0.84, 0.54)</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row1_col3" class="data row1 col3" >-0.140000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row2_col0" class="data row2 col0" >0.100000</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row2_col1" class="data row2 col1" >25</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row2_col2" class="data row2 col2" >(0.72, 0.69)</td>
#                         <td id="T_b8f43c12_6558_11ea_93fd_38c9861cb017row2_col3" class="data row2 col3" >-0.330000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Extended Example

# %%
# %load annulus.py
import math, random
from vector import add, norm, normed, dotprod
from activation_function import heaviside


def get_annulus_segment_points(x=0.0, y=0.0, r0=0.0, r1=1.0, a0=0.0, a1=math.pi, n=250):
    P = []
    for _ in range(n):
        a, s = random.uniform(a0, a1), random.uniform(r0, r1)
        P.append((x + s * math.cos(a), y + s * math.sin(a)))
    return P


def get_annulus_test_data(x=0.4, y=-0.4, r0=1.1, r1=1.5, n=125):
    A0 = get_annulus_segment_points(r0=r0, r1=r1, n=n)
    A1 = get_annulus_segment_points(x=x, y=y, a0=math.pi, a1=2 * math.pi, r0=r0, r1=r1, n=n)
    T = [(u, 1) for u in A0] + [(u, 0) for u in A1]
    random.shuffle(T)
    return A0, A1, T


def verify_annulus_classification(A0, A1, w, b, classify=heaviside):
    assert all(classify(dotprod(w, x) + b) == 1 for x in A0) and all(classify(dotprod(w, x) + b) == 0 for x in A1)

# %%
import matplotlib
import matplotlib.pyplot as plot


def plot_annulus_classification(A0, A1, w, b, t=2.0, size=(6, 6)):
    def ln(x):
        return -x * w[0] / w[1] - b / w[1]

    w, b = normed(w), b / norm(w)
    fig = plot.figure()
    fig.set_size_inches(*size)
    ax = plot.axes()
    ax.set_aspect('equal')
    plot.title(f"Seperating Hyperplane w={_rnd(w)}, b={_rnd(b)}")
    plot.grid()
    plot.xlim(-t, t)
    plot.ylim(-t, t)
    plot.plot([x for x, _ in A0], [y for _, y in A0], "x", color="tab:red")
    plot.plot([x for x, _ in A1], [y for _, y in A1], "x", color="tab:blue")
    plot.plot([-t, t], [ln(-t), ln(t)], color="black")
    ax.arrow(0.0, -b / w[1], w[0], w[1], head_width=0.1, head_length=0.15, fc='black', ec='black')
    plot.show()

# %%
n = 250
A0, A1, T = get_annulus_test_data(n=n)

# %%
from perceptron import perceptron

w, b = perceptron(T, s=s, epochs=epochs)
plot_annulus_classification(A0, A1, w, b)
verify_annulus_classification(A0, A1, w, b, classify=heaviside)

# %%
n = 250
A0, A1, T = get_annulus_test_data(n=n)

s, epochs = 0.01, 10
a, da, classify = sigmoid, dx_sigmoid, heaviside

w, b = delta_rule(T, a=a, da=da, s=s, epochs=epochs)
plot_annulus_classification(A0, A1, w, b)
verify_annulus_classification(A0, A1, w, b, classify=heaviside)

# %%
n = 250
A0, A1, T = get_annulus_test_data(n=n)

s, epochs = 0.01, 15
a, da, classify = lambda x: 0.5 * linear(x) + 0.5, lambda x: 0.5 * dx_linear(x), heaviside

w, b = delta_rule(T, a=a, da=da, s=s, epochs=epochs)
plot_annulus_classification(A0, A1, w, b)
verify_annulus_classification(A0, A1, w, b, classify=classify)

# %%
n = 250
A0, A1, T = get_annulus_test_data(n=n)

s, epochs = 0.01, 15
offset = 0.42
a, da, classify = relu, dx_relu, lambda x: heaviside(x, offset=offset)

w, b = delta_rule(T, a=a, da=da, s=s, epochs=epochs)
plot_annulus_classification(A0, A1, w, b - offset)
verify_annulus_classification(A0, A1, w, b, classify=classify)
